# %%
import pandas as pd

# %%
conso_sheets_list = ['Primary Energy Consumption',
                     'Oil Consumption - EJ',
                     'Gas Consumption - EJ',
                     'Coal Consumption - EJ',
                     'Nuclear Consumption - EJ',
                     'Hydro Consumption - EJ',
                     'Solar Consumption - EJ',
                     'Wind Consumption - EJ',
                     'Geo Biomass Other - EJ',
                     'Biofuels Consumption - PJ']

def excel_to_dataframe(sheet:str):
  df = pd.read_excel('data_brut/bp-stats-review-2020-all-data.xlsx',
                    sheet_name=sheet,
                    skiprows=[0,1], skipfooter=8)
  df = df.drop(['2019.1','2008-18','2019.2'],axis=1)
  df = df.transpose()
  new_header = df.iloc[0]
  df = df[1:]
  df.columns = new_header
  df = df.dropna(1,how='all')
  df = df.dropna(0, how='all')
  return df

data_list = []
for sheet in conso_sheets_list:
  clean_df = excel_to_dataframe(sheet)
  data_list.append(clean_df)

# %%
data_list[1]
# Out:
# Exajoules   Canada    Mexico       US Total North America Argentina    Brazil  \
# 1965       2.31414  0.642414  23.6918             26.6484  0.936501   0.63983
# 1966       2.43814  0.673178   24.876             27.9873  0.966833  0.697671
# 1967       2.60318  0.720995  25.8376             29.1618  0.990672   0.71997
# 1968       2.77126  0.784022  27.6306             31.1859   1.01163  0.864706
# 1969       2.88556   0.82857  29.1356             32.8497   1.05113  0.948844
# 1970       3.07728  0.890909  30.3008              34.269  0.943775   1.07359
# 1971       3.16026  0.944772  31.3418             35.4469   1.00791   1.18294
# 1972        3.3276   1.06385  33.8633             38.2547   1.00929   1.36072
# 1973         3.512   1.13848  35.7461             40.3966   1.01274   1.67519
# 1974        3.5714   1.28611  34.3162             39.1737   1.01629   1.80662
# 1975       3.49687   1.41916  33.6526             38.5686  0.957385   1.86496
# ...

# %%
energy_types = ['Primary', 'Oil', 'Gas', 'Coal', 'Nuclear', 'Hydro', 'Solar', 'Wind', 'Geo Biomass', 'Biofuel']
types_df = pd.DataFrame(energy_types)
types_df.rename(columns={0 : 'name'}, inplace=True)
types_df
types_df.to_csv("Sauvegardes_clean_csv/energy_types.csv")

# %%
#conversion en PJ

def PJ_to_EJ(x):
    return x * 0.001

data_list[9] = PJ_to_EJ(data_list[9])

# %%
energy_types = ['Primary', 'Oil', 'Gas', 'Coal', 'Nuclear', 'Hydro', 'Solar', 'Wind', 'Geo Biomass', 'Biofuel']

locations_to_drop=[  'Total North America',
'Total S. & Cent. America',
 'Total Europe',
  'Total Middle East',
'Total Africa',
'Total Asia Pacific',
 'Total World',
 'of which: OECD',
 '                 Non-OECD',
 '                 European Union #'
                  'European Union'
                  'Europe',' of which: OECD',
       '                Non-OECD', '                European Union',
       'Canada & Mexico', 'Other S. & Cent. America', 'Europe',
       'CIS', 'Middle East', 'Africa', 'Asia Pacific',
       '                Non-OECD', '                European Union',
       'Canada & Mexico', 'Other S. & Cent. America', 'Europe',
       'CIS', 'Middle East', 'Africa', 'Asia Pacific','Total Europe ','Total CIS','                 European Union #']

n=0

for df in data_list:
    df.rename_axis(types[n] + " EJ", axis="columns", inplace = True)
    n+=1
    
    for location in  locations_to_drop:
        try:
            df.drop([location], axis=1, inplace = True )
        except KeyError:
            pass
    
                   
#dropping 2 last columns Brazil and US in Biofuel df
cols = [26]

data_list[9].drop(df.columns[cols],axis=1,inplace=True)

data_list[9].columns
# Out:
# Index(['Canada', 'Mexico', 'Argentina', 'Colombia', 'Austria', 'Belgium',
#        'Finland', 'France', 'Germany', 'Italy', 'Netherlands', 'Poland',
#        'Portugal', 'Spain', 'Sweden', 'United Kingdom', 'Other Europe',
#        'Australia', 'China', 'India', 'Indonesia', 'South Korea', 'Thailand',
#        'Other Asia Pacific'],
#       dtype='object', name='Biofuel EJ')

# %%
# Sauvegarde en CSV
types = ['Primary', 'Oil', 'Gas', 'Coal', 'Nuclear', 'Hydro', 'Solar', 'Wind', 'Geo Biomass', 'Biofuel']
n=0

for df in data_list:
    
    df.to_csv("Sauvegardes_clean_csv/cons_csv/"+ types[n]+".csv")
    n += 1

# %%
list_country = ['Canada',
 'Mexico',
 'US',
 'Argentina',
 'Brazil',
 'Colombia',
 'Ecuador',
 'Peru',
 'Trinidad & Tobago',
 'Venezuela',
 'Denmark',
 'Italy',
 'Norway',
 'Romania',
 'United Kingdom',
 'Other Europe',
 'Azerbaijan',
 'Kazakhstan',
 'Russian Federation',
 'Turkmenistan',
 'USSR',
 'Uzbekistan',
 'Other CIS',
 'Iran',
 'Iraq',
 'Kuwait',
 'Oman',
 'Qatar',
 'Saudi Arabia',
 'Syria',
 'United Arab Emirates',
 'Yemen',
 'Other Middle East',
 'Algeria',
 'Angola',
 'Chad',
 'Republic of Congo ',
 'Egypt',
 'Equatorial Guinea',
 'Gabon',
 'Libya',
 'Nigeria',
 'South Sudan',
 'Sudan',
 'Tunisia',
 'Other Africa',
 'Australia',
 'Brunei',
 'China',
 'India',
 'Indonesia',
 'Malaysia',
 'Thailand',
 'Vietnam',
 'Other Asia Pacific',
 'Bolivia',
 'Germany',
 'Netherlands',
 'Poland',
 'Ukraine',
 'Bahrain',
 'Bangladesh',
 'Myanmar',
 'Pakistan',
 'Bulgaria',
 'Czech Republic',
 'Greece',
 'Hungary',
 'Serbia',
 'Spain',
 'Turkey',
 'South Africa',
 'Zimbabwe',
 'Japan',
 'Mongolia',
 'New Zealand',
 'South Korea',
 'Chile',
 'Central America',
 'Other Caribbean',
 'Other South America',
 'Austria',
 'Belgium',
 'Croatia',
 'Cyprus',
 'Estonia',
 'Finland',
 'France',
 'Iceland',
 'Ireland',
 'Latvia',
 'Lithuania',
 'Luxembourg',
 'North Macedonia',
 'Portugal',
 'Slovakia',
 'Slovenia',
 'Sweden',
 'Switzerland',
 'Belarus',
 'Israel',
 'Morocco',
 'Eastern Africa',
 'Middle Africa',
 'Western Africa',
 'Other Northern Africa',
 'Other Southern Africa',
 'China Hong Kong SAR',
 'Philippines',
 'Singapore',
 'Sri Lanka',
 'Taiwan']

# %%
locations_df = pd.DataFrame(list_country)

dic = {'Canada':1,
 'Mexico':1,
 'US':1,
 'Argentina':2,
 'Brazil':2,
 'Colombia':2,
 'Ecuador':2,
 'Peru':2,
 'Trinidad & Tobago':2,
 'Venezuela':2,
 'Denmark':3,
 'Italy':3,
 'Norway':3,
 'Romania':3,
 'United Kingdom':3,
 'Other Europe':3,
 'Azerbaijan':4,
 'Kazakhstan':4,
 'Russian Federation':4,
 'Turkmenistan':4,
 'USSR':4,
 'Uzbekistan':4,
 'Other CIS':4,
 'Iran':5,
 'Iraq':5,
 'Kuwait':5,
 'Oman':5,
 'Qatar':5,
 'Saudi Arabia':5,
 'Syria':5,
 'United Arab Emirates':5,
 'Yemen':5,
 'Other Middle East':5,
 'Algeria':6,
 'Angola':6,
 'Chad':6,
 'Republic of Congo ':6,
 'Egypt':6,
 'Equatorial Guinea':6,
 'Gabon':6,
 'Libya':6,
 'Nigeria':6,
 'South Sudan':6,
 'Sudan':6,
 'Tunisia':6,
 'Other Africa':6,
 'Australia':7,
 'Brunei':7,
 'China':7,
 'India':7,
 'Indonesia':7,
 'Malaysia':7,
 'Thailand':7,
 'Vietnam':7,
 'Other Asia Pacific':7,
 'Bolivia':2,
 'Germany':3,
 'Netherlands':3,
 'Poland':3,
 'Ukraine':3,
 'Bahrain':5,
 'Bangladesh':7,
 'Myanmar':7,
 'Pakistan':7,
 'Bulgaria':3,
 'Czech Republic':3,
 'Greece':3,
 'Hungary':3,
 'Serbia':3,
 'Spain':3,
 'Turkey':3,
 'South Africa':6,
 'Zimbabwe':6,
 'Japan':7,
 'Mongolia':7,
 'New Zealand':7,
 'South Korea':7,
 'Chile':2,
 'Central America':2,
 'Other Caribbean':2,
 'Other South America':2,
 'Austria':3,
 'Belgium':3,
 'Croatia':3,
 'Cyprus':3,
 'Estonia':3,
 'Finland':3,
 'France':3,
 'Iceland':3,
 'Ireland':3,
 'Latvia':3,
 'Lithuania':3,
 'Luxembourg':3,
 'North Macedonia':3,
 'Portugal':3,
 'Slovakia':3,
 'Slovenia':3,
 'Sweden':3,
 'Switzerland':3,
 'Belarus':3,
 'Israel':5,
 'Morocco':6,
 'Eastern Africa':6,
 'Middle Africa':6,
 'Western Africa':6,
 'Other Northern Africa':6,
 'Other Southern Africa':6,
 'China Hong Kong SAR':7,
 'Philippines':7,
 'Singapore':7,
 'Sri Lanka':7,
 'Taiwan':7}



locations_df['region_id']=locations_df

# %%
locations_df.rename(columns={0:'name'},inplace=True)

# %%
locations_df['region_id']= locations_df['region_id'].map(dic)
locations_df
# Out:
#                     name  region_id
# 0                 Canada          1
# 1                 Mexico          1
# 2                     US          1
# 3              Argentina          2
# 4                 Brazil          2
# ..                   ...        ...
# 107  China Hong Kong SAR          7
# 108          Philippines          7
# 109            Singapore          7
# 110            Sri Lanka          7
# 111               Taiwan          7
#
# [112 rows x 2 columns]

# %%
locations_df.to_csv("Sauvegardes_clean_csv/locations.csv")

# %%
regions= ['North America',
'S. & Cent. America',
'Europe',
'CIS',
'Middle East',
'Africa',
'Asia Pacific',
]

regions_df = pd.DataFrame(regions)

regions_df.rename(columns={0:'name'}, inplace = True)

regions_df.to_csv("Sauvegardes_clean_csv/regions.csv")
