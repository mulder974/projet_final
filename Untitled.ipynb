# %%
import pandas as pd

# %%
data = pd.read_csv("owid-energy-data.csv", index_col=0)

# %%
data
# Out:
#               country  year  coal_prod_change_pct  coal_prod_change_twh  \
# iso_code
# AFG       Afghanistan  1980               -35.709                -0.384
# AFG       Afghanistan  1981                 5.042                 0.035
# AFG       Afghanistan  1982                16.000                 0.116
# AFG       Afghanistan  1983                 0.000                 0.000
# AFG       Afghanistan  1984                 2.069                 0.017
# ...               ...   ...                   ...                   ...
# ZWE          Zimbabwe  2012               -37.800                -7.262
# ZWE          Zimbabwe  2013                95.419                11.403
# ZWE          Zimbabwe  2014                85.685                20.010
# ZWE          Zimbabwe  2015               -25.013               -10.847
# ZWE          Zimbabwe  2016               -37.694               -12.257
#
#           gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# iso_code
# ...

# %%
data.co
